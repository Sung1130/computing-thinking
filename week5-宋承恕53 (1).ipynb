# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bca0e2660b9f> in <module>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
a=1
a
# Out:
# 1

# %%
a="Python"
a
# Out:
# 'Python'

# %%
a=123
b=123.456
c="Python"
d=False

# %%
a=1
print(a, id(a))
b="Python"
print(b, id(b))
# Out:
# 1 10968800
# Python 140121093835832

# %%
x=1
y=2
print(id(x), id(y))
# Out:
# 10968800 10968832

# %%
z=1
print(id(x), id(z))
# Out:
# 10968800 10968800

# %%
x=18
sys.getsizeof(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-04c227b3e5bf> in <module>()
#       1 x=18
# ----> 2 sys.getsizeof(x)
#
# NameError: name 'sys' is not defined

# %%
print(False)
print(True)
print(False+3)
print(True+3)
print(False==0)
print(True==1)
# Out:
# False
# True
# 3
# 4
# True
# True

# %%
a = 100
b = 100.001

# %%
s1 = '春眠不覺曉,處處聞啼鳥。'
print(s1)
s2 = "夜來風雨聲,花落知多少。"
print(s2)
s3 = '作者"孟浩然" 詩名"春曉"'
print(s3)
s4 = "作者'孟浩然' 詩名'春曉'"
print(s4)
s5 = ''' 春眠不覺曉,處處聞啼鳥。
夜來風雨聲,花落知多少。
作者"孟浩然" 詩名"春曉"
'''
print(s5)
# Out:
# 春眠不覺曉,處處聞啼鳥。
# 夜來風雨聲,花落知多少。
# 作者"孟浩然" 詩名"春曉"
# 作者'孟浩然' 詩名'春曉'
#  春眠不覺曉,處處聞啼鳥。
# 夜來風雨聲,花落知多少。
# 作者"孟浩然" 詩名"春曉"

# %%
a = 123
b = 123.456
print(a)
print("b=", b)
print(a, b, end = '.')
# Out:
# 123
# b= 123.456
# 123 123.456.

# %%
print("宋承恕")
print("宋 \n 承恕")
print("宋 \t 承恕")
# Out:
# 宋承恕
# 宋
#  承恕
# 宋 	 承恕

# %%
s = input()
s
# Out:
# hi
# 'hi'

# %%
s = input("Enter Your Name:")
s
# Out:
# Enter Your Name:宋承恕
# '宋承恕'

# %%
s = input ("Enter Your Name:")
print("Hi,", s)
# Out:
# Enter Your Name:宋承恕
# Hi, 宋承恕

# %%
s = input ("Enter Your Number:")
print(s+100)
# Out:
# Enter Your Number:123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1a730fa1c753> in <module>()
#       1 s = input ("Enter Your Number:")
# ----> 2 print(s+100)
#
# TypeError: must be str, not int

# %%
s = int(input("Enter Your Number:"))
print(100 + s)
s = float(input("Enter Your Number:"))
print(100 + s)
s = eval(input("Enter Your Number:"))
print(100 + s)
s = eval(input("Enter Your Number:"))
print(100 + s)
# Out:
# Enter Your Number:123
# 223
# Enter Your Number:123
# 223.0
# Enter Your Number:123
# 223
# Enter Your Number:123.0
# 223.0
